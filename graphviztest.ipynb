# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import graphviz

g = graphviz.Digraph('G', filename='hello.gv')

g.edge('Hello', 'World')

display(g)

# %%
import graphviz
def pHHMviz(priors,states):
    g = graphviz.Digraph('G', filename='hello.gv')
    init = priors[0]
    tran = priors[1]
    emis = priors[2]
    for key in init:
        g.edge('start',str(key),label=str(init(key)))
    display(g)
